# %% [markdown]
# ## Chapter 9 Tuples, Files, and Everything Else

# %% [raw]
# The tuple, a collection of other objects that cannot be changed
# The file, an interface to external files on your computer.

# %% [markdown]
# They work exactly like lists, except that tuples can't be changed in-place (i.e., they are immutable). One of the most important characteristics about tuple is that they are written as a series of items in parentheses, not square brackets.

# %% [markdown]
# Tuples are:
# 1. oredered collections of arbitary objects.
# Like strings and lists, positionally ordered.
# 2. Accessed by offset
# not by key. they support all the offset-based access operations, such as indexing and slicing.
# 3. Of the category "immutable sequence"
# Like strings and lists, tuples are sequences; they support many of the same operations. However, like strings, tuples are immutable; they don't support any of the in-place change operations applied to lists.
# 4. Fixed-length, hetergeneous and arbitrarily nestable.
# Because tuples are immutable, you cannot change the size of a tuple with making a copy. And arbitrary nesting.
# 5. Arrays of object references
# Like lists, tuples are best thought of as object reference arrays; tuples store access points to other objects (references), and indexing a tuple is relatively quick.

# %% [markdown]
# Table 9-1 Common tuple literals and operations.

# %%
T = ()  # An empty tuple
len(T)
# Out:
# 0

# %%
T= (0,) # A one-item tuple (not an expression)

# %%
len(T)
# Out:
# 1

# %%
T = (0,'Ni',1.2, 3) # A four-item tuple

# %%
len(T)
# Out:
# 4

# %%
T = 0, 'Ni', 1.2, 3 # Another four-item tuple (same as prior line)
print(T, len(T))
# Out:
# (0, 'Ni', 1.2, 3) 4

# %%
T = ('abc', ('def','ghi')) # Nested tuples?

# %%
T = tuple("""Table 9-1 highlights common tuple operations. A tuple is written as a series of objects
(technically, expressions that generate objects), separated by commas and normally
enclosed in parentheses. An empty tuple is just a parentheses pair with nothing inside.""")

# %%
print(T,len(T))
# Out:
# ('T', 'a', 'b', 'l', 'e', ' ', '9', '-', '1', ' ', 'h', 'i', 'g', 'h', 'l', 'i', 'g', 'h', 't', 's', ' ', 'c', 'o', 'm', 'm', 'o', 'n', ' ', 't', 'u', 'p', 'l', 'e', ' ', 'o', 'p', 'e', 'r', 'a', 't', 'i', 'o', 'n', 's', '.', ' ', 'A', ' ', 't', 'u', 'p', 'l', 'e', ' ', 'i', 's', ' ', 'w', 'r', 'i', 't', 't', 'e', 'n', ' ', 'a', 's', ' ', 'a', ' ', 's', 'e', 'r', 'i', 'e', 's', ' ', 'o', 'f', ' ', 'o', 'b', 'j', 'e', 'c', 't', 's', '\n', '(', 't', 'e', 'c', 'h', 'n', 'i', 'c', 'a', 'l', 'l', 'y', ',', ' ', 'e', 'x', 'p', 'r', 'e', 's', 's', 'i', 'o', 'n', 's', ' ', 't', 'h', 'a', 't', ' ', 'g', 'e', 'n', 'e', 'r', 'a', 't', 'e', ' ', 'o', 'b', 'j', 'e', 'c', 't', 's', ')', ',', ' ', 's', 'e', 'p', 'a', 'r', 'a', 't', 'e', 'd', ' ', 'b', 'y', ' ', 'c', 'o', 'm', 'm', 'a', 's', ' ', 'a', 'n', 'd', ' ', 'n', 'o', 'r', 'm', 'a', 'l', 'l', 'y', '\n', 'e', 'n', 'c', 'l', 'o', 's', 'e', 'd', ' ', 'i', 'n', ' ', 'p', 'a', 'r', 'e', 'n', 't', 'h', 'e', 's', 'e', 's', '.', ' ', 'A', 'n', ' ', 
# ...

# %%
print(T[0],T[1],T[4])
# Out:
# T a e

# %%
T1 = tuple(tuple("""Table 9-1 highlights common tuple operations. A tuple is written as a series of objects
(technically, expressions that generate objects), separated by commas and normally
enclosed in parentheses. An empty tuple is just a parentheses pair with nothing inside."""))

# %%
print(T1, end='')
# Out:
# ('T', 'a', 'b', 'l', 'e', ' ', '9', '-', '1', ' ', 'h', 'i', 'g', 'h', 'l', 'i', 'g', 'h', 't', 's', ' ', 'c', 'o', 'm', 'm', 'o', 'n', ' ', 't', 'u', 'p', 'l', 'e', ' ', 'o', 'p', 'e', 'r', 'a', 't', 'i', 'o', 'n', 's', '.', ' ', 'A', ' ', 't', 'u', 'p', 'l', 'e', ' ', 'i', 's', ' ', 'w', 'r', 'i', 't', 't', 'e', 'n', ' ', 'a', 's', ' ', 'a', ' ', 's', 'e', 'r', 'i', 'e', 's', ' ', 'o', 'f', ' ', 'o', 'b', 'j', 'e', 'c', 't', 's', '\n', '(', 't', 'e', 'c', 'h', 'n', 'i', 'c', 'a', 'l', 'l', 'y', ',', ' ', 'e', 'x', 'p', 'r', 'e', 's', 's', 'i', 'o', 'n', 's', ' ', 't', 'h', 'a', 't', ' ', 'g', 'e', 'n', 'e', 'r', 'a', 't', 'e', ' ', 'o', 'b', 'j', 'e', 'c', 't', 's', ')', ',', ' ', 's', 'e', 'p', 'a', 'r', 'a', 't', 'e', 'd', ' ', 'b', 'y', ' ', 'c', 'o', 'm', 'm', 'a', 's', ' ', 'a', 'n', 'd', ' ', 'n', 'o', 'r', 'm', 'a', 'l', 'l', 'y', '\n', 'e', 'n', 'c', 'l', 'o', 's', 'e', 'd', ' ', 'i', 'n', ' ', 'p', 'a', 'r', 'e', 'n', 't', 'h', 'e', 's', 'e', 's', '.', ' ', 'A', 'n', ' ', 
# ...

# %%
T1 == T
# Out:
# True

# %%
T2 = T, T1

# %%
print(T2, end = ' ')
# Out:
# (('T', 'a', 'b', 'l', 'e', ' ', '9', '-', '1', ' ', 'h', 'i', 'g', 'h', 'l', 'i', 'g', 'h', 't', 's', ' ', 'c', 'o', 'm', 'm', 'o', 'n', ' ', 't', 'u', 'p', 'l', 'e', ' ', 'o', 'p', 'e', 'r', 'a', 't', 'i', 'o', 'n', 's', '.', ' ', 'A', ' ', 't', 'u', 'p', 'l', 'e', ' ', 'i', 's', ' ', 'w', 'r', 'i', 't', 't', 'e', 'n', ' ', 'a', 's', ' ', 'a', ' ', 's', 'e', 'r', 'i', 'e', 's', ' ', 'o', 'f', ' ', 'o', 'b', 'j', 'e', 'c', 't', 's', '\n', '(', 't', 'e', 'c', 'h', 'n', 'i', 'c', 'a', 'l', 'l', 'y', ',', ' ', 'e', 'x', 'p', 'r', 'e', 's', 's', 'i', 'o', 'n', 's', ' ', 't', 'h', 'a', 't', ' ', 'g', 'e', 'n', 'e', 'r', 'a', 't', 'e', ' ', 'o', 'b', 'j', 'e', 'c', 't', 's', ')', ',', ' ', 's', 'e', 'p', 'a', 'r', 'a', 't', 'e', 'd', ' ', 'b', 'y', ' ', 'c', 'o', 'm', 'm', 'a', 's', ' ', 'a', 'n', 'd', ' ', 'n', 'o', 'r', 'm', 'a', 'l', 'l', 'y', '\n', 'e', 'n', 'c', 'l', 'o', 's', 'e', 'd', ' ', 'i', 'n', ' ', 'p', 'a', 'r', 'e', 'n', 't', 'h', 'e', 's', 'e', 's', '.', ' ', 'A', 'n', ' ',
# ...

# %%
T3 = ((T1,T2),(T, T1),(T2,T))

# %%
print(T3, end = ' ')
# Out:
# ((('T', 'a', 'b', 'l', 'e', ' ', '9', '-', '1', ' ', 'h', 'i', 'g', 'h', 'l', 'i', 'g', 'h', 't', 's', ' ', 'c', 'o', 'm', 'm', 'o', 'n', ' ', 't', 'u', 'p', 'l', 'e', ' ', 'o', 'p', 'e', 'r', 'a', 't', 'i', 'o', 'n', 's', '.', ' ', 'A', ' ', 't', 'u', 'p', 'l', 'e', ' ', 'i', 's', ' ', 'w', 'r', 'i', 't', 't', 'e', 'n', ' ', 'a', 's', ' ', 'a', ' ', 's', 'e', 'r', 'i', 'e', 's', ' ', 'o', 'f', ' ', 'o', 'b', 'j', 'e', 'c', 't', 's', '\n', '(', 't', 'e', 'c', 'h', 'n', 'i', 'c', 'a', 'l', 'l', 'y', ',', ' ', 'e', 'x', 'p', 'r', 'e', 's', 's', 'i', 'o', 'n', 's', ' ', 't', 'h', 'a', 't', ' ', 'g', 'e', 'n', 'e', 'r', 'a', 't', 'e', ' ', 'o', 'b', 'j', 'e', 'c', 't', 's', ')', ',', ' ', 's', 'e', 'p', 'a', 'r', 'a', 't', 'e', 'd', ' ', 'b', 'y', ' ', 'c', 'o', 'm', 'm', 'a', 's', ' ', 'a', 'n', 'd', ' ', 'n', 'o', 'r', 'm', 'a', 'l', 'l', 'y', '\n', 'e', 'n', 'c', 'l', 'o', 's', 'e', 'd', ' ', 'i', 'n', ' ', 'p', 'a', 'r', 'e', 'n', 't', 'h', 'e', 's', 'e', 's', '.', ' ', 'A', 'n', ' '
# ...

# %%
len(T3)
# Out:
# 3

# %%
print(T1 + T2, end = '') # Cpncatenate, repeat
# Out:
# ('T', 'a', 'b', 'l', 'e', ' ', '9', '-', '1', ' ', 'h', 'i', 'g', 'h', 'l', 'i', 'g', 'h', 't', 's', ' ', 'c', 'o', 'm', 'm', 'o', 'n', ' ', 't', 'u', 'p', 'l', 'e', ' ', 'o', 'p', 'e', 'r', 'a', 't', 'i', 'o', 'n', 's', '.', ' ', 'A', ' ', 't', 'u', 'p', 'l', 'e', ' ', 'i', 's', ' ', 'w', 'r', 'i', 't', 't', 'e', 'n', ' ', 'a', 's', ' ', 'a', ' ', 's', 'e', 'r', 'i', 'e', 's', ' ', 'o', 'f', ' ', 'o', 'b', 'j', 'e', 'c', 't', 's', '\n', '(', 't', 'e', 'c', 'h', 'n', 'i', 'c', 'a', 'l', 'l', 'y', ',', ' ', 'e', 'x', 'p', 'r', 'e', 's', 's', 'i', 'o', 'n', 's', ' ', 't', 'h', 'a', 't', ' ', 'g', 'e', 'n', 'e', 'r', 'a', 't', 'e', ' ', 'o', 'b', 'j', 'e', 'c', 't', 's', ')', ',', ' ', 's', 'e', 'p', 'a', 'r', 'a', 't', 'e', 'd', ' ', 'b', 'y', ' ', 'c', 'o', 'm', 'm', 'a', 's', ' ', 'a', 'n', 'd', ' ', 'n', 'o', 'r', 'm', 'a', 'l', 'l', 'y', '\n', 'e', 'n', 'c', 'l', 'o', 's', 'e', 'd', ' ', 'i', 'n', ' ', 'p', 'a', 'r', 'e', 'n', 't', 'h', 'e', 's', 'e', 's', '.', ' ', 'A', 'n', ' ', 
# ...

# %%
print(T1*3, end =' ') # Repeat
# Out:
# ('T', 'a', 'b', 'l', 'e', ' ', '9', '-', '1', ' ', 'h', 'i', 'g', 'h', 'l', 'i', 'g', 'h', 't', 's', ' ', 'c', 'o', 'm', 'm', 'o', 'n', ' ', 't', 'u', 'p', 'l', 'e', ' ', 'o', 'p', 'e', 'r', 'a', 't', 'i', 'o', 'n', 's', '.', ' ', 'A', ' ', 't', 'u', 'p', 'l', 'e', ' ', 'i', 's', ' ', 'w', 'r', 'i', 't', 't', 'e', 'n', ' ', 'a', 's', ' ', 'a', ' ', 's', 'e', 'r', 'i', 'e', 's', ' ', 'o', 'f', ' ', 'o', 'b', 'j', 'e', 'c', 't', 's', '\n', '(', 't', 'e', 'c', 'h', 'n', 'i', 'c', 'a', 'l', 'l', 'y', ',', ' ', 'e', 'x', 'p', 'r', 'e', 's', 's', 'i', 'o', 'n', 's', ' ', 't', 'h', 'a', 't', ' ', 'g', 'e', 'n', 'e', 'r', 'a', 't', 'e', ' ', 'o', 'b', 'j', 'e', 'c', 't', 's', ')', ',', ' ', 's', 'e', 'p', 'a', 'r', 'a', 't', 'e', 'd', ' ', 'b', 'y', ' ', 'c', 'o', 'm', 'm', 'a', 's', ' ', 'a', 'n', 'd', ' ', 'n', 'o', 'r', 'm', 'a', 'l', 'l', 'y', '\n', 'e', 'n', 'c', 'l', 'o', 's', 'e', 'd', ' ', 'i', 'n', ' ', 'p', 'a', 'r', 'e', 'n', 't', 'h', 'e', 's', 'e', 's', '.', ' ', 'A', 'n', ' ', 
# ...

# %%
for x in T: print(x, sep = '=>',end = '')
# Out:
# Table 9-1 highlights common tuple operations. A tuple is written as a series of objects
# (technically, expressions that generate objects), separated by commas and normally
# enclosed in parentheses. An empty tuple is just a parentheses pair with nothing inside.

# %%
'spam' in T
# Out:
# False

# %%
print(T)
[x**2 for x in (23,45)]
# Out:
# ('T', 'a', 'b', 'l', 'e', ' ', '9', '-', '1', ' ', 'h', 'i', 'g', 'h', 'l', 'i', 'g', 'h', 't', 's', ' ', 'c', 'o', 'm', 'm', 'o', 'n', ' ', 't', 'u', 'p', 'l', 'e', ' ', 'o', 'p', 'e', 'r', 'a', 't', 'i', 'o', 'n', 's', '.', ' ', 'A', ' ', 't', 'u', 'p', 'l', 'e', ' ', 'i', 's', ' ', 'w', 'r', 'i', 't', 't', 'e', 'n', ' ', 'a', 's', ' ', 'a', ' ', 's', 'e', 'r', 'i', 'e', 's', ' ', 'o', 'f', ' ', 'o', 'b', 'j', 'e', 'c', 't', 's', '\n', '(', 't', 'e', 'c', 'h', 'n', 'i', 'c', 'a', 'l', 'l', 'y', ',', ' ', 'e', 'x', 'p', 'r', 'e', 's', 's', 'i', 'o', 'n', 's', ' ', 't', 'h', 'a', 't', ' ', 'g', 'e', 'n', 'e', 'r', 'a', 't', 'e', ' ', 'o', 'b', 'j', 'e', 'c', 't', 's', ')', ',', ' ', 's', 'e', 'p', 'a', 'r', 'a', 't', 'e', 'd', ' ', 'b', 'y', ' ', 'c', 'o', 'm', 'm', 'a', 's', ' ', 'a', 'n', 'd', ' ', 'n', 'o', 'r', 'm', 'a', 'l', 'l', 'y', '\n', 'e', 'n', 'c', 'l', 'o', 's', 'e', 'd', ' ', 'i', 'n', ' ', 'p', 'a', 'r', 'e', 'n', 't', 'h', 'e', 's', 'e', 's', '.', ' ', 'A', 'n', ' ', 
# ...

# %%
T.index('a')
# Out:
# 1

# %%
T.count('a')
# Out:
# 16

# %%
conda install -c bjodah pyodesys pytest

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
X=np.linspace(-100,100,256,endpoint=True)

# %%
C = np.exp(-2*np.sqrt(2*(1.4*10**(-4)))*X)

# %%
plt.plot(X,C)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

flights_long=sns.load_dataset("flights")
flights=flights_long.pivot("month","year","passengers")

sns.heatmap(flights,annot=True,fmt="d",linewidths=.5)
plt.show()

# %%
import yt

# %%
from sympy import *

# %%
x, y, z = symbols('x y z')

# %%
init_printing(use_unicode=True)

# %% [markdown]
# ## Tuples in Action

# %% [markdown]
# Because tuples are immutable, they don't have any kind of in-place operations. You cannot change a tuple without making a copy. Nevertheless, they do support the usual sequence operations that we saw for both strings and lists.

# %%
(1,2) + (3,4) # Concatenation
# Out:
# (1, 2, 3, 4)

# %%
(1,2)*4 # Repetition
# Out:
# (1, 2, 1, 2, 1, 2, 1, 2)

# %%
T= (1,2,3,4) # Indexing, slicing

# %%
T[0], T[1:3]
# Out:
# (1, (2, 3))

# %% [markdown]
# Tuple syntax peculiarities: Commas and parentheses

# %%
x = (40)  # An integer !
y = (40,)

# %%
type(x), type(y)  # A tuple containing an integer
# Out:
# (int, tuple)

# %% [markdown]
# ## Conversions, methods, and immutability

# %%
T = ('cc','aa','dd','bb')

# %%
tmp = list(T) # Make a list from a tuple's items

# %%
tmp.sort()

# %%
tmp
# Out:
# ['aa', 'bb', 'cc', 'dd']

# %%
T = tuple(tmp)

# %%
T
# Out:
# ('aa', 'bb', 'cc', 'dd')

# %%
sorted(T) # Or use the sorted built-in
# Out:
# ['aa', 'bb', 'cc', 'dd']

# %%
T = (1,2,3,4,5)

# %%
L = [x + 20 for x in T]

# %%
L
# Out:
# [21, 22, 23, 24, 25]

# %%
T = (1,2,3,2,4,2) # Tuple methods in 2.6 and 3.0

# %%
T.index(2) #Offset of first apperance of 2
# Out:
# 1

# %%
T1 = T.index(1), T.index(2), T.index(3), T.index(2), T.index(4)

# %%
T1
# Out:
# (0, 1, 2, 1, 4)

# %%
T.count(2)
# Out:
# 3

# %%
T = (1,[2,3],4)

# %%
T[1]
# T[1] = 'spam'  # 'tuple' object does not support item assignment
# Out:
# [2, 3]

# %%
T[1][0] = 'spam' # This works: can change mutable inside

# %%
print(T)
# Out:
# (1, ['spam', 3], 4)

# %% [markdown]
# The best answer, however, seems to be that the immutability of tuples provides some
# integrity—you can be sure a tuple won’t be changed through another reference elsewhere in a program, but there’s no such guarantee for lists. Tuples, therefore, serve asimilar role to “constant” declarations in other languages, though the notion of constantness is associated with objects in Python, not variables.

# %% [markdown]
# # Files

# %% [markdown]
# You may already be familiar with the notion of files, which are named storage compartments on your computer that are managed by your operating system. The last major built-in object type that we’ll examine on our object types tour provides a way to access those files inside Python programs.

# %%
output = open(r'C:\Users\NickC\RF-Tutorial.ipynb','r')

# %%
output.read()
# Out:
# '{\n "cells": [\n  {\n   "cell_type": "markdown",\n   "metadata": {},\n   "source": [\n    "This is a brief tutorial regarding the use of Random Forest to develop new scoring function.\\n",\n    "Needs to install Anaconda (https://www.continuum.io/downloads , python version 3.6)\\n",\n    "\\n",\n    "#install package\\n",\n    "\\n",\n    "conda install numpy matplotlib\\n",\n    "\\n",\n    "conda install scipy scikit-learn seaborn\\n",\n    "\\n",\n    "conda install -c conda-forge xgboost=0.6a2\\n",\n    "\\n",\n    "conda install -c conda-forge pydotplus\\n",\n    "\\n",\n    "#open the notebook in yourfolder\\n",\n    "\\n",\n    "jupyter notebook\\n"\n   ]\n  },\n  {\n   "cell_type": "code",\n   "execution_count": 11,\n   "metadata": {},\n   "outputs": [\n    {\n     "name": "stdout",\n     "output_type": "stream",\n     "text": [\n      "Collecting package metadata (current_repodata.json): ...working... done\\n",\n      "Solving environment: ...working... done\\n",\n      "\\
# ...

# %%
output.read(3)
output.close()

# %%
R = input('Please entire a string')
# Out:
# Please entire a string Compared to the types you’ve seen so far, file objects are somewhat unusual. They’re not numbers, sequences, or mappings, and they don’t respond to expression operators; they export only methods for common file-processing tasks. Most file methods are concerned with performing input from and output to the external file associated with a file object, but other file methods allow us to seek to a new position in the file, flush output buffers, and so on. Table 9-2 summarizes common file operations.\

# %%
R
# Out:
# 'Compared to the types you’ve seen so far, file objects are somewhat unusual. They’re not numbers, sequences, or mappings, and they don’t respond to expression operators; they export only methods for common file-processing tasks. Most file methods are concerned with performing input from and output to the external file associated with a file object, but other file methods allow us to seek to a new position in the file, flush output buffers, and so on. Table 9-2 summarizes common file operations.\\'

# %%
R1 = open('1.dat')

# %%
R1.read()
# Out:
# 'do\x0
# ...

# %%
Astring=open('1.dir').read(1000) # Read up to Next N charaters (or a bytes) into a string

# %%
Astring1= open('1.dir').read()

# %%
print(Astring)
# Out:
# '1', (0, 2)
# '2', (512, 2)
# '3', (1024, 3)
# '4', (1536, 4)
# '5', (2048, 4)
# '6', (2560, 2)
# '7', (3072, 6)
# '8', (3584, 3)
# '9', (4096, 6)
# '10', (4608, 6)
# '11', (5120, 4)
# '12', (5632, 3)
# '13', (6144, 4)
# '14', (6656, 4)
# '15', (7168, 4)
# '16', (7680, 4)
# '17', (8192, 2)
# '18', (8704, 2)
# '19', (9216, 2)
# '20', (9728, 5)
# '21', (10240, 7)
# '22', (10752, 10)
# '23', (11264, 2)
# '24', (11776, 4)
# '25', (12288, 2)
# '26', (12800, 5)
# '27', (13312, 5)
# '28', (13824, 2)
# '29', (14336, 7)
# '30', (14848, 28)
# '31', (15360, 3)
# '32', (15872, 7)
# '33', (16384, 14)
# '34', (16896, 7)
# '35', (17408, 18)
# '36', (17920, 7)
# '37', (18432, 6)
# '38', (18944, 7)
# '39', (19456, 10)
# '40', (19968, 2)
# '41', (20480, 5)
# '42', (20992, 9)
# '43', (21504, 4)
# '44', (22016, 4)
# '45', (22528, 6)
# '46', (23040, 5)
# '47', (23552, 13)
# '48', (24064, 3)
# '49', (24576, 8)
# '50', (25088, 6)
# '51', (25600, 7)
# '52', (26112, 2)
# '53', (26624, 4)
# '54', (27136, 4)
# ...

# %%
print(Astring1,end='')
# Out:
# '1', (0, 2)
# '2', (512, 2)
# '3', (1024, 3)
# '4', (1536, 4)
# '5', (2048, 4)
# '6', (2560, 2)
# '7', (3072, 6)
# '8', (3584, 3)
# '9', (4096, 6)
# '10', (4608, 6)
# '11', (5120, 4)
# '12', (5632, 3)
# '13', (6144, 4)
# '14', (6656, 4)
# '15', (7168, 4)
# '16', (7680, 4)
# '17', (8192, 2)
# '18', (8704, 2)
# '19', (9216, 2)
# '20', (9728, 5)
# '21', (10240, 7)
# '22', (10752, 10)
# '23', (11264, 2)
# '24', (11776, 4)
# '25', (12288, 2)
# '26', (12800, 5)
# '27', (13312, 5)
# '28', (13824, 2)
# '29', (14336, 7)
# '30', (14848, 28)
# '31', (15360, 3)
# '32', (15872, 7)
# '33', (16384, 14)
# '34', (16896, 7)
# '35', (17408, 18)
# '36', (17920, 7)
# '37', (18432, 6)
# '38', (18944, 7)
# '39', (19456, 10)
# '40', (19968, 2)
# '41', (20480, 5)
# '42', (20992, 9)
# '43', (21504, 4)
# '44', (22016, 4)
# '45', (22528, 6)
# '46', (23040, 5)
# '47', (23552, 13)
# '48', (24064, 3)
# '49', (24576, 8)
# '50', (25088, 6)
# '51', (25600, 7)
# '52', (26112, 2)
# '53', (26624, 4)
# '54', (27136, 4)
# ...

# %%
Astring2 = open('1.dir').readlines()

# %%
Astring3 = open('1.dir').readlines(500)

# %%
Astring3
# Out:
# ["'1', (0, 2)\n",
#  "'2', (512, 2)\n",
#  "'3', (1024, 3)\n",
#  "'4', (1536, 4)\n",
#  "'5', (2048, 4)\n",
#  "'6', (2560, 2)\n",
#  "'7', (3072, 6)\n",
#  "'8', (3584, 3)\n",
#  "'9', (4096, 6)\n",
#  "'10', (4608, 6)\n",
#  "'11', (5120, 4)\n",
#  "'12', (5632, 3)\n",
#  "'13', (6144, 4)\n",
#  "'14', (6656, 4)\n",
#  "'15', (7168, 4)\n",
#  "'16', (7680, 4)\n",
#  "'17', (8192, 2)\n",
#  "'18', (8704, 2)\n",
#  "'19', (9216, 2)\n",
#  "'20', (9728, 5)\n",
#  "'21', (10240, 7)\n",
#  "'22', (10752, 10)\n",
#  "'23', (11264, 2)\n",
#  "'24', (11776, 4)\n",
#  "'25', (12288, 2)\n",
#  "'26', (12800, 5)\n",
#  "'27', (13312, 5)\n",
#  "'28', (13824, 2)\n",
#  "'29', (14336, 7)\n",
#  "'30', (14848, 28)\n",
#  "'31', (15360, 3)\n",
#  "'32', (15872, 7)\n"]

# %%
open('1.txt').read()
# Out:
# "{'1': 'do', '2': 'to', '3': 'has', '4': 'name', '5': 'this', '6': 'of', '7': 'origin', '8': 'The', '9': 'known.', '10': 'widely', '11': 'most', '12': 'are', '13': 'they', '14': 'that', '15': 'name', '16': 'this', '17': 'by', '18': 'is', '19': 'it', '20': 'since', '21': 'forces,', '22': 'dispersion', '23': 'as', '24': 'them', '25': 'to', '26': 'refer', '27': 'shall', '28': 'We', '29': 'forces.', '30': 'induceddipole-induced-dipole', '31': 'and', '32': 'forces,', '33': 'electrodynamic', '34': 'forces,', '35': 'charge-fluctuation', '36': 'forces,', '37': 'London', '38': 'forces,', '39': 'dispersion', '40': 'as', '41': 'known', '42': 'variously', '43': 'been', '44': 'have', '45': 'forces', '46': 'These', '47': 'hydrocarbons.', '48': 'and', '49': 'dioxide,', '50': 'carbon', '51': 'helium,', '52': 'as', '53': 'such', '54': 'ones', '55': 'neutral', '56': 'totally', '57': 'even', '58': 'molecules,', '59': 'and', '60': 'atoms', '61': 'all', '62': 'between', '63': 'force鈥攁cts', '64': 'gravita
# ...

# %%
open('1.txt').read(200)
# Out:
# "{'1': 'do', '2': 'to', '3': 'has', '4': 'name', '5': 'this', '6': 'of', '7': 'origin', '8': 'The', '9': 'known.', '10': 'widely', '11': 'most', '12': 'are', '13': 'they', '14': 'that', '15': 'name', '"

# %%
open('1.txt').readline()
# Out:
# "{'1': 'do', '2': 'to', '3': 'has', '4': 'name', '5': 'this', '6': 'of', '7': 'origin', '8': 'The', '9': 'known.', '10': 'widely', '11': 'most', '12': 'are', '13': 'they', '14': 'that', '15': 'name', '16': 'this', '17': 'by', '18': 'is', '19': 'it', '20': 'since', '21': 'forces,', '22': 'dispersion', '23': 'as', '24': 'them', '25': 'to', '26': 'refer', '27': 'shall', '28': 'We', '29': 'forces.', '30': 'induceddipole-induced-dipole', '31': 'and', '32': 'forces,', '33': 'electrodynamic', '34': 'forces,', '35': 'charge-fluctuation', '36': 'forces,', '37': 'London', '38': 'forces,', '39': 'dispersion', '40': 'as', '41': 'known', '42': 'variously', '43': 'been', '44': 'have', '45': 'forces', '46': 'These', '47': 'hydrocarbons.', '48': 'and', '49': 'dioxide,', '50': 'carbon', '51': 'helium,', '52': 'as', '53': 'such', '54': 'ones', '55': 'neutral', '56': 'totally', '57': 'even', '58': 'molecules,', '59': 'and', '60': 'atoms', '61': 'all', '62': 'between', '63': 'force鈥攁cts', '64': 'gravita
# ...

# %%
open('1.txt').readlines(20)
# Out:
# ["{'1': 'do', '2': 'to', '3': 'has', '4': 'name', '5': 'this', '6': 'of', '7': 'origin', '8': 'The', '9': 'known.', '10': 'widely', '11': 'most', '12': 'are', '13': 'they', '14': 'that', '15': 'name', '16': 'this', '17': 'by', '18': 'is', '19': 'it', '20': 'since', '21': 'forces,', '22': 'dispersion', '23': 'as', '24': 'them', '25': 'to', '26': 'refer', '27': 'shall', '28': 'We', '29': 'forces.', '30': 'induceddipole-induced-dipole', '31': 'and', '32': 'forces,', '33': 'electrodynamic', '34': 'forces,', '35': 'charge-fluctuation', '36': 'forces,', '37': 'London', '38': 'forces,', '39': 'dispersion', '40': 'as', '41': 'known', '42': 'variously', '43': 'been', '44': 'have', '45': 'forces', '46': 'These', '47': 'hydrocarbons.', '48': 'and', '49': 'dioxide,', '50': 'carbon', '51': 'helium,', '52': 'as', '53': 'such', '54': 'ones', '55': 'neutral', '56': 'totally', '57': 'even', '58': 'molecules,', '59': 'and', '60': 'atoms', '61': 'all', '62': 'between', '63': 'force鈥攁cts', '64': 'gravit
# ...

# %%
open('1.txt','w').write("""'101': 'We are the last survior'""")
# Out:
# 32

# %%
open('1.txt').read()
# Out:
# "'101': 'We are the last survior'"

# %%
open('1.txt','w').write(""""{'1': 'do', '2': 'to', '3': 'has', '4': 'name', '5': 'this', '6': 'of', '7': 'origin', '8': 'The', '9': 'known.', '10': 'widely', '11': 'most', '12': 'are', '13': 'they', '14': 'that', '15': 'name', '16': 'this', '17': 'by', '18': 'is', '19': 'it', '20': 'since', '21': 'forces,', '22': 'dispersion', '23': 'as', '24': 'them', '25': 'to', '26': 'refer', '27': 'shall', '28': 'We', '29': 'forces.', '30': 'induceddipole-induced-dipole', '31': 'and', '32': 'forces,', '33': 'electrodynamic', '34': 'forces,', '35': 'charge-fluctuation', '36': 'forces,', '37': 'London', '38': 'forces,', '39': 'dispersion', '40': 'as', '41': 'known', '42': 'variously', '43': 'been', '44': 'have', '45': 'forces', '46': 'These', '47': 'hydrocarbons.', '48': 'and', '49': 'dioxide,', '50': 'carbon', '51': 'helium,', '52': 'as', '53': 'such', '54': 'ones', '55': 'neutral', '56': 'totally', '57': 'even', '58': 'molecules,', '59': 'and', '60': 'atoms', '61': 'all', '62': 'between', '63': 'force鈥攁cts', '64': 'gravitational', '65': 'the', '66': 'that鈥攍ike', '67': 'force', '68': 'of', '69': 'type', '70': 'another', '71': 'a', '72': 'is', '73': 'there', '74': 'But', '75': 'molecules.', '76': 'dipolar', '77': 'or', '78': 'charged', '79': 'involving', '80': 'interactions', '81': 'electrostatic', '82': 'straightforward', '83': 'from', '84': 'arise', '85': 'they', '86': 'since', '87': 'understand,', '88': 'to', '89': 'easy', '90': 'fairly', '91': 'are', '92': 'far', '93': 'so', '94': 'described', '95': 'forces', '96': 'physical', '97': 'of', '98': 'types', '99': 'various', '100': 'The'}""")
# Out:
# 1572

# %%
Astring = open('2.txt','w')

# %%
astring = Astring.write(input("""type anything you like"""))
# Out:
# type anything you like In short, the built-in open function creates a Python file object, which serves as a link to a file residing on your machine. After calling open, you can transfer strings of data to and from the associated external file by calling the returned file object’s methods.

# %%
Astring.close()

# %%
open("2.txt",'r').read()
# Out:
# 'In short, the built-in open function creates a Python file object, which serves as a link to a file residing on your machine. After calling open, you can transfer strings of data to and from the associated external file by calling the returned file object’s methods.'

# %%
open('2.txt','r').flush()

# %%
open('2.txt','r').read()
# Out:
# 'In short, the built-in open function creates a Python file object, which serves as a link to a file residing on your machine. After calling open, you can transfer strings of data to and from the associated external file by calling the returned file object’s methods.'

# %%
open('1.dir','r').readlines()
# Out:
# ["'1', (0, 2)\n",
#  "'2', (512, 2)\n",
#  "'3', (1024, 3)\n",
#  "'4', (1536, 4)\n",
#  "'5', (2048, 4)\n",
#  "'6', (2560, 2)\n",
#  "'7', (3072, 6)\n",
#  "'8', (3584, 3)\n",
#  "'9', (4096, 6)\n",
#  "'10', (4608, 6)\n",
#  "'11', (5120, 4)\n",
#  "'12', (5632, 3)\n",
#  "'13', (6144, 4)\n",
#  "'14', (6656, 4)\n",
#  "'15', (7168, 4)\n",
#  "'16', (7680, 4)\n",
#  "'17', (8192, 2)\n",
#  "'18', (8704, 2)\n",
#  "'19', (9216, 2)\n",
#  "'20', (9728, 5)\n",
#  "'21', (10240, 7)\n",
#  "'22', (10752, 10)\n",
#  "'23', (11264, 2)\n",
#  "'24', (11776, 4)\n",
#  "'25', (12288, 2)\n",
#  "'26', (12800, 5)\n",
#  "'27', (13312, 5)\n",
#  "'28', (13824, 2)\n",
#  "'29', (14336, 7)\n",
#  "'30', (14848, 28)\n",
#  "'31', (15360, 3)\n",
#  "'32', (15872, 7)\n",
#  "'33', (16384, 14)\n",
#  "'34', (16896, 7)\n",
#  "'35', (17408, 18)\n",
#  "'36', (17920, 7)\n",
#  "'37', (18432, 6)\n",
#  "'38', (18944, 7)\n",
#  "'39', (19456, 10)\n",
#  "'40', (19968, 2)\n",
#  "'41', (20480, 5)\n",
# ...

# %%
open('1.dir','r').read()
# Out:
# "'1', (0, 2)\n'2', (512, 2)\n'3', (1024, 3)\n'4', (1536, 4)\n'5', (2048, 4)\n'6', (2560, 2)\n'7', (3072, 6)\n'8', (3584, 3)\n'9', (4096, 6)\n'10', (4608, 6)\n'11', (5120, 4)\n'12', (5632, 3)\n'13', (6144, 4)\n'14', (6656, 4)\n'15', (7168, 4)\n'16', (7680, 4)\n'17', (8192, 2)\n'18', (8704, 2)\n'19', (9216, 2)\n'20', (9728, 5)\n'21', (10240, 7)\n'22', (10752, 10)\n'23', (11264, 2)\n'24', (11776, 4)\n'25', (12288, 2)\n'26', (12800, 5)\n'27', (13312, 5)\n'28', (13824, 2)\n'29', (14336, 7)\n'30', (14848, 28)\n'31', (15360, 3)\n'32', (15872, 7)\n'33', (16384, 14)\n'34', (16896, 7)\n'35', (17408, 18)\n'36', (17920, 7)\n'37', (18432, 6)\n'38', (18944, 7)\n'39', (19456, 10)\n'40', (19968, 2)\n'41', (20480, 5)\n'42', (20992, 9)\n'43', (21504, 4)\n'44', (22016, 4)\n'45', (22528, 6)\n'46', (23040, 5)\n'47', (23552, 13)\n'48', (24064, 3)\n'49', (24576, 8)\n'50', (25088, 6)\n'51', (25600, 7)\n'52', (26112, 2)\n'53', (26624, 4)\n'54', (27136, 4)\n'55', (27648, 7)\n'56', (28160, 7)\n'57', (28672, 4)
# ...

# %%
for line in open('1.dir','r'):
    print(line, end='')
# Out:
# '1', (0, 2)
# '2', (512, 2)
# '3', (1024, 3)
# '4', (1536, 4)
# '5', (2048, 4)
# '6', (2560, 2)
# '7', (3072, 6)
# '8', (3584, 3)
# '9', (4096, 6)
# '10', (4608, 6)
# '11', (5120, 4)
# '12', (5632, 3)
# '13', (6144, 4)
# '14', (6656, 4)
# '15', (7168, 4)
# '16', (7680, 4)
# '17', (8192, 2)
# '18', (8704, 2)
# '19', (9216, 2)
# '20', (9728, 5)
# '21', (10240, 7)
# '22', (10752, 10)
# '23', (11264, 2)
# '24', (11776, 4)
# '25', (12288, 2)
# '26', (12800, 5)
# '27', (13312, 5)
# '28', (13824, 2)
# '29', (14336, 7)
# '30', (14848, 28)
# '31', (15360, 3)
# '32', (15872, 7)
# '33', (16384, 14)
# '34', (16896, 7)
# '35', (17408, 18)
# '36', (17920, 7)
# '37', (18432, 6)
# '38', (18944, 7)
# '39', (19456, 10)
# '40', (19968, 2)
# '41', (20480, 5)
# '42', (20992, 9)
# '43', (21504, 4)
# '44', (22016, 4)
# '45', (22528, 6)
# '46', (23040, 5)
# '47', (23552, 13)
# '48', (24064, 3)
# '49', (24576, 8)
# '50', (25088, 6)
# '51', (25600, 7)
# '52', (26112, 2)
# '53', (26624, 4)
# '54', (27136, 4)
# ...

# %%
print(open('1.dir',encoding='latin-1'))
# Out:
# <_io.TextIOWrapper name='1.dir' mode='r' encoding='latin-1'>

# %%
open('1.txt', encoding = 'latin-1')
# Out:
# <_io.TextIOWrapper name='1.txt' mode='r' encoding='latin-1'>

# %%
open('tasks.db','rb')
# Out:
# <_io.BufferedReader name='tasks.db'>

# %% [markdown]
# ### File iterators are best for reading lines
# Though the reading and writing methods in the table are common, keep in mind
# that probably the best way to read lines from a text file today is to not read the file
# at all—as we’ll see in Chapter 14, files also have an iterator that automatically reads
# one line at a time in a for loop, list comprehension, or other iteration context.

# %%
for line in open('1.txt','r'):
    print(line, end='')
# Out:
# Using Files
# Once you make a file object with open, you can call its methods to read from or write
# to the associated external file. In all cases, file text takes the form of strings in Python
# programs; reading a file returns its text in strings, and text is passed to the write methods
# as strings. Reading and writing methods come in multiple flavors; Table 9-2 lists the
# most common. Here are a few fundamental usage notes:
# File iterators are best for reading lines
# Though the reading and writing methods in the table are common, keep in mind
# that probably the best way to read lines from a text file today is to not read the file
# at all鈥攁s we鈥檒l see in Chapter 14, files also have an iterator that automatically reads
# one line at a time in a for loop, list comprehension, or other iteration context.
# Content is strings, not objects
# Notice in Table 9-2 that data read from a file always comes back to your script as
# ...

# %%
Astring = open('1.dir','r').readline()
type(Astring)
# Out:
# str

# %%
Astrings = open('1.dir','r').readlines()
type(Astrings)
# Out:
# list

# %%
Astring2 = open('1.dir','r').read()
type(Astring2)
# Out:
# str

# %%
#!/usr/bin/env python
#-*- coding:UTF-8 -*-
import webbrowser
url = 'http://www.sci-hub.ren/'
hub = 'http://www.sci-hub.ren/'
webbrowser.open(url)
print(webbrowser.get())
doi = "10.1103/PhysRevLett.115.164502" 
paper = hub + doi 
#字符串的拼接

webbrowser.open(paper)
# Out:
# ...
# True

# %%
import webbrowser
chromePath = r'C:\Users\NickC\AppData\Local\Google\Chrome\Application\chrome.exe'
webbrowser.register('chrome', None, webbrowser.BackgroundBrowser(chromePath))
webbrowser.get('chrome').open(paper,new=1, autoraise=True)
# Out:
# True

# %%
import lassie
data = lassie.fetch('https://github.com/s0md3v/Photon')
print(data) 
print([i['src'] for i in data['images']])
# Out:
# {'images': [{'src': 'https://avatars2.githubusercontent.com/u/26716802?s=400&v=4', 'type': 'og:image'}, {'src': 'https://github.githubassets.com/favicon.ico', 'type': 'favicon'}], 'videos': [], 'site_name': 'GitHub', 'title': 's0md3v/Photon', 'url': 'https://github.com/s0md3v/Photon', 'description': 'Incredibly fast crawler designed for OSINT. Contribute to s0md3v/Photon development by creating an account on GitHub.', 'locale': 'en_US', 'status_code': 200}
# ['https://avatars2.githubusercontent.com/u/26716802?s=400&v=4', 'https://github.githubassets.com/favicon.ico']

# %% [markdown]
# ## Close is usually optional

# %% [markdown]
# Calling the file close method terminates your connection to the external file. As
# discussed in Chapter 6, in Python an object’s memory space is automatically reclaimed as soon as the object is no longer referenced anywhere in the program.
# When file objects are reclaimed, Python also automatically closes the files if they
# are still open (this also happens when a program shuts down). This means you
# Files | 231don’t always need to manually close your files, especially in simple scripts that
# don’t run for long. On the other hand, including manual close calls can’t hurt and
# is usually a good idea in larger systems. Also, strictly speaking, this auto-close-oncollection feature of files is not part of the language definition, and it may change
# over time. Consequently, manually issuing file close method calls is a good habit
# to form. (For an alternative way to guarantee automatic file closes, also see this
# section’s later discussion of the file object’s context manager, used with the new
# with/as statement in Python 2.6 and 3.0.)

# %%
from wordcloud import WordCloud
import PIL.Image as image

with open(r'C:\Users\NickC\Desktop\wordcloud.txt') as fp:
          text=fp.read()
          print(text)
# Out:
# Betty Botter bought some butter but she said the butter's bitter. If I put it in my batter it will make my batter bitter. So, she bought some better butter, better than the bitter butter and she put it in her batter and her batter was not bitter. So 'twas good that Betty Botter bought some better butter.

# %%
from wordcloud import WordCloud
import PIL.Image as image

with open(r'C:\Users\NickC\Desktop\wordcloud.txt') as fp:
          text=fp.read()
          #print(text)
          #将文本放入WordCoud容器对象中并分析
          WordCloud = WordCloud().generate(text)
          image_produce = WordCloud.to_image()
          image_produce.show()

# %%
from wordcloud import WordCloud
import PIL.Image as image
import numpy as np

with open(r'C:\Users\NickC\Desktop\wordcloud.txt') as fp:
    text = fp.read()
    # print(text)
    mask = np.array(image.open(r'C:\Users\NickC\Desktop\1.png'))
    wordcloud = WordCloud(
        mask=mask
    ).generate(text)
    image_produce = wordcloud.to_image()
    image_produce.show()

# %%
from wordcloud import WordCloud
import PIL .Image as image
import numpy as np
import jieba

def trans_CN(text):
    word_list = jieba.cut(text)
    # 分词后在单独个体之间加上空格
    result = " ".join(word_list)
    return result;


with open(r'C:\Users\NickC\alice.txt','r',encoding='UTF-8') as fp:
    text = fp.read()
    text  = trans_CN(text)
    # print(text)
    mask = np.array(image.open(r'C:\Users\NickC\Desktop\1.png'))
    wordcloud = WordCloud(
        mask=mask,
        font_path = "C:/Windows/Fonts/simfang.ttf"
    ).generate(text)
    image_produce = wordcloud.to_image()
    image_produce.show()

# %%
from os import path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import jieba
from wordcloud import WordCloud, STOPWORDS


###当前文件路径
#d = path.dirname(__file__)

# Read the whole text.
file = open(r'C:\Users\NickC\alice1.txt', encoding='utf-8').read()
##进行分词
#刚开始是分完词放进txt再打开却总是显示不出中文很奇怪
default_mode =jieba.cut(file)
text = " ".join(default_mode)
alice_mask = np.array(Image.open(r'C:\Users\NickC\1.png'))
stopwords = set(STOPWORDS)
stopwords.add("said")
wc = WordCloud(  
    #设置字体，不指定就会出现乱码,这个字体文件需要下载
    font_path="C:/Windows/Fonts/simfang.ttf",  
    background_color="white",   
    max_words=2000,   
    mask=alice_mask,  
    stopwords=stopwords)  
# generate word cloud
wc.generate(text)

# store to file
wc.to_file(r'C:\Users\NickC\Desktop\qq_result.jpg')

# show
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.figure()
plt.imshow(alice_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
#!/usr/bin/Python
# -*- coding: utf-8 -*-
from os import path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import jieba
from wordcloud import WordCloud, STOPWORDS


###当前文件路径
d = path.dirname(r'C:\Users\NickC\k')

# Read the whole text.
file = open(path.join(d, 'alice.txt'),'r',encoding='UTF-8').read()
##进行分词
#刚开始是分完词放进txt再打开却总是显示不出中文很奇怪
default_mode =jieba.cut(file)
text = " ".join(default_mode)
alice_mask = np.array(Image.open(path.join(d, "1.png")))
stopwords = set(STOPWORDS)
stopwords.add("said")
wc = WordCloud(  
    #设置字体，不指定就会出现乱码,这个字体文件需要下载
    font_path="C:/Windows/Fonts/simfang.ttf",  
    background_color="white",   
    max_words=2000,   
    mask=alice_mask,  
    stopwords=stopwords)  
# generate word cloud
wc.generate(text)

# store to file
wc.to_file(path.join(d, "qq_result.jpg"))

# show
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.figure()
plt.imshow(alice_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
path.dirname(r'C:\Users\NickC\k')
# Out:
# 'C:\\Users\\NickC'

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt  #绘制图像的模块
import  jieba                    #jieba分词

path_txt='C://Users/NickC/alice.txt'
f = open(path_txt,'r',encoding='UTF-8').read()

# 结巴分词，生成字符串，wordcloud无法直接生成正确的中文词云
cut_text = " ".join(jieba.cut(f))

wordcloud = WordCloud(
   #设置字体，不然会出现口字乱码，文字的路径是电脑的字体一般路径，可以换成别的
   font_path="C:/Windows/Fonts/simfang.ttf",
   #设置了背景，宽高
   background_color="black",width=4000,height=1880).generate(cut_text)

plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
from PIL import Image
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt
import numpy as np
import  jieba
def GetWordCloud():
   path_txt = 'C://Users/NickC/alice.txt'
   path_img = 'C://Users/NickC/1.png'
   f = open(path_txt, 'r', encoding='UTF-8').read()
   background_image = np.array(Image.open(path_img))
   # 结巴分词，生成字符串，如果不通过分词，无法直接生成正确的中文词云,感兴趣的朋友可以去查一下，有多种分词模式
   #Python join() 方法用于将序列中的元素以指定的字符连接生成一个新的字符串。
   cut_text = " ".join(jieba.cut(f))

   wordcloud = WordCloud(
       # 设置字体，不然会出现口字乱码，文字的路径是电脑的字体一般路径，可以换成别的
       font_path="C:/Windows/Fonts/simfang.ttf",
       background_color="white",
       # mask参数=图片背景，必须要写上，另外有mask参数再设定宽高是无效的
       mask=background_image).generate(cut_text)
   # 生成颜色值
   image_colors = ImageColorGenerator(background_image)
   # 下面代码表示显示图片
   plt.imshow(wordcloud.recolor(color_func=image_colors), interpolation="bilinear")
   plt.axis("off")
   plt.show()

if __name__ == '__main__':
   GetWordCloud()

# %%
import turtle as t

import time

t.color("red", "yellow")

t.speed(10)

t.begin_fill()

for _ in range(50):

  t.forward(200)

  t.left(170)

t.end_fill()

time.sleep(1)

# %%
import turtle as t
import time
R = 150
r = R - 10

t.pensize(10)
t.color("black","white")
t.speed(10)
t.circle(R,360) # 画圆圈
t.penup()
t.left(90)
t.forward(R)
t.pensize(1)
t.pendown()
t.forward(R)
t.pensize(1)
t.fillcolor("black")
# 左侧三角形
t.begin_fill()
t.left(170)
t.forward(r)
t.right(180)
t.forward(r)
t.right(170)
t.forward(R)
t.right(60)
t.forward(R)
t.right(170)
t.forward(r)
t.end_fill()
# 下面三角形
t.right(180)
t.forward(r)
t.begin_fill()
t.left(160)
t.forward(r)
t.right(180)
t.forward(r)
t.right(170)
t.forward(R)
t.right(60)
t.forward(R)
t.right(170)
t.forward(r)
t.end_fill()
# 右边三角形
t.right(180)
t.forward(r)
t.begin_fill()
t.left(160)
t.forward(r)
t.right(180)
t.forward(r)
t.right(170)
t.forward(R)
t.right(60)
t.forward(R)
t.right(170)
t.forward(r)
t.end_fill()

t.hideturtle() # 隐藏小海龟画笔
t.mainloop()

# %%
import turtle as t
t.pensize(1)
for i in range(1,300,2):
    t.left(90)
    t.fd(i*2)

# %%
import turtle
import time

def head():
    
    #配置画笔属性
    turtle.fillcolor("black")
    turtle.color("black")
    turtle.colormode(255)
    turtle.speed(1)

    #绘制母企鹅头部
    turtle.penup()
    turtle.goto(-300,350)
    turtle.seth(0)
    turtle.pendown()
    turtle.begin_fill()
    turtle.circle(-200,-110)   
    turtle.penup()
    turtle.goto(-300,350)
    turtle.pendown()
    turtle.seth(0)
    turtle.circle(-200,110) 
    turtle.seth(213)
    turtle.circle(-345,66)
    turtle.end_fill()


def lefteye():

    #配置画笔属性
    turtle.Turtle().screen.delay(0)
    turtle.fillcolor("white")
    turtle.speed(1)
    turtle.colormode(255)

    #绘制母企鹅的左眼
    turtle.pu()
    turtle.goto(-350,275)
    turtle.seth(180)
    turtle.pd()
    turtle.begin_fill()

    #画椭圆
    a=1.0
    for i in range(120):
        if 0<=i<30 or 60<=i<90:
            a=a+0.08
            turtle.lt(3) #向左转3度
            turtle.fd(a) #向前走a的步长
        else:
            a=a-0.08
            turtle.lt(3)
            turtle.fd(a)
    turtle.pu()
    turtle.end_fill()
    
    #绘制左眼眼影
    turtle.begin_fill()
    turtle.fillcolor("pink")
    turtle.pu()
    turtle.goto(-378,255)
    turtle.pendown()
    turtle.color("pink")
    turtle.seth(15)
    turtle.circle(-100,35)
    turtle.pu()
    turtle.goto(-350,275)
    turtle.seth(180)
    a=1
    for i in range(20):
        if 0<=i<30 or 60<=i<90:
            a=a+0.08
            turtle.lt(3) 
            turtle.fd(a) 
        else:
            a=a-0.08
            turtle.lt(3)
            turtle.fd(a)
    turtle.goto(-350,275)
    turtle.seth(0)
    a=1
    for i in range(20):
        if 0<=i<30 or 60<=i<90:
            a=a+0.08
            turtle.rt(3) 
            turtle.fd(a) 
        else:
            a=a-0.08
            turtle.lt(3)
            turtle.fd(a)
    turtle.pu()
    turtle.end_fill()

    #绘制睫毛
    turtle.pu()
    turtle.goto(-350,275)
    turtle.seth(180)
    turtle.pd()
    a=1
    for i in range(20):
        if 0<=i<30 or 60<=i<90:
            a=a+0.08
            turtle.lt(3) 
            turtle.fd(a) 
        else:
            a=a-0.08
            turtle.lt(3)
            turtle.fd(a)
    turtle.pensize(3)
    turtle.color(242,156,177)
    turtle.circle(-20,190)
    turtle.pensize(1)

    #绘制母企鹅的左眼珠
    turtle.color("black")
    turtle.fillcolor("black")
    turtle.begin_fill()
    turtle.pu()
    turtle.goto(-330,245)
    turtle.seth(180)
    turtle.pd()
    turtle.begin_fill() 
    a=0.01
    for i in range(120):
        if 0<=i<30 or 60<=i<90:
            a=a+0.05
            turtle.lt(3) 
            turtle.fd(a) 
        else:
            a=a-0.05
            turtle.lt(3)
            turtle.fd(a)
    turtle.pu()
    turtle.end_fill()
    

def righteye():
    
    #配置画笔属性
    turtle.Turtle().screen.delay(0)
    turtle.fillcolor("white")
    turtle.speed(1)
    turtle.colormode(255)

    #绘制母企鹅的右眼
    turtle.pu()
    turtle.goto(-250,275)
    turtle.seth(180)
    turtle.pd()
    turtle.begin_fill()

    a=1.0
    for i in range(120):
        if 0<=i<30 or 60<=i<90:
            a=a+0.08
            turtle.lt(3) 
            turtle.fd(a) 
        else:
            a=a-0.08
            turtle.lt(3)
            turtle.fd(a)
    turtle.pu()
    turtle.end_fill()
    
    #绘制右眼眼影
    turtle.begin_fill()
    turtle.fillcolor("pink")
    turtle.pu()
    turtle.goto(-278,255)
    turtle.pendown()
    turtle.color("pink")
    turtle.seth(15)
    turtle.circle(-100,35)
    turtle.pu()
    turtle.goto(-250,275)
    turtle.seth(180)
    a=1
    for i in range(20):
        if 0<=i<30 or 60<=i<90:
            a=a+0.08
            turtle.lt(3) 
            turtle.fd(a) 
        else:
            a=a-0.08
            turtle.lt(3)
            turtle.fd(a)
    turtle.goto(-250,275)
    turtle.seth(0)
    a=1
    for i in range(20):
        if 0<=i<30 or 60<=i<90:
            a=a+0.08
            turtle.rt(3) 
            turtle.fd(a) 
        else:
            a=a-0.08
            turtle.lt(3)
            turtle.fd(a)
    turtle.pu()
    turtle.end_fill()

    #绘制睫毛
    turtle.pu()
    turtle.goto(-250,275)
    turtle.seth(0)
    turtle.pd()
    a=1
    for i in range(20):
        if 0<=i<30 or 60<=i<90:
            a=a+0.08
            turtle.rt(3) #向左转3度
            turtle.fd(a) #向前走a的步长
        else:
            a=a-0.08
            turtle.lt(3)
            turtle.fd(a)
    turtle.pensize(3)
    turtle.color(242,156,177)
    turtle.circle(20,190)
    turtle.pensize(1)

    #绘制母企鹅的右眼珠
    turtle.color("black")
    turtle.fillcolor("black")
    turtle.begin_fill()
    turtle.pu()
    turtle.goto(-270,245)
    turtle.seth(180)
    turtle.pd()
    turtle.begin_fill() 
    a=0.01
    for i in range(120):
        if 0<=i<30 or 60<=i<90:
            a=a+0.05
            turtle.lt(3) 
            turtle.fd(a) 
        else:
            a=a-0.05
            turtle.lt(3)
            turtle.fd(a)
    turtle.pu()
    turtle.end_fill()
    

def mouth():

    #配置画笔属性
    turtle.fillcolor((250,175,8)) 
    turtle.color((250,175,8))
    turtle.speed(1)
    turtle.colormode(255)

    #绘制母企鹅的嘴巴
    turtle.pu()
    turtle.goto(-410,120)
    turtle.seth(30)
    turtle.pd()
    turtle.begin_fill() 
    turtle.circle(-225,60)
    turtle.circle(-8,150)
    turtle.seth(210)
    turtle.circle(-225,60)
    turtle.seth(-210)
    turtle.circle(-8,150)
    turtle.pu()
    turtle.end_fill()


def bowknot():

    #配置画笔属性
    turtle.speed(1)
    turtle.fillcolor("pink")
    turtle.pu()
    turtle.color("pink")
    turtle.goto(-250,360)
    turtle.pd()
    turtle.seth(225)

    #绘制蝴蝶结的上半部分
    turtle.begin_fill()
    turtle.fillcolor("pink")
    turtle.pu()
    turtle.goto(-250,360)
    turtle.pd()
    turtle.circle(-70,100)
    turtle.seth(50)
    turtle.circle(-80,53)
    turtle.pu()
    turtle.goto(-250,360)
    turtle.seth(50)
    turtle.pd()
    turtle.circle(70,100)
    turtle.seth(225)
    turtle.circle(80,53)
    turtle.end_fill()

    #绘制蝴蝶结下半部分
    turtle.pu()
    turtle.goto(-195,335)
    turtle.pd()
    turtle.begin_fill()
    turtle.fillcolor("pink")
    turtle.seth(45)
    turtle.circle(-70,100)
    turtle.seth(230)
    turtle.circle(-80,62.5)
    turtle.pu()
    turtle.goto(-195,335)
    turtle.seth(225)
    turtle.pd()
    turtle.circle(70,100)
    turtle.seth(50)
    turtle.circle(80,58)
    turtle.end_fill()
    
    #蝴蝶结的中间部分
    turtle.begin_fill()
    turtle.fillcolor("pink")
    turtle.pu()
    turtle.color("pink")
    turtle.goto(-255,370)
    turtle.pd()
    turtle.seth(225)
    turtle.circle(40,360)
    turtle.end_fill()
    
def scarf():

    #配置画笔属性
    turtle.fillcolor("pink") 
    turtle.color("pink")
    turtle.speed(1)
    turtle.colormode(255)

    #绘制围巾
    turtle.pu()
    turtle.goto(-489,82)
    turtle.seth(-115)
    turtle.pd()
    turtle.begin_fill() 
    turtle.fd(75)
    turtle.seth(-30)
    turtle.circle(450,10)
    turtle.seth(-90)
    turtle.fd(100)
    turtle.seth(-35)
    turtle.circle(50,70)
    turtle.seth(90)
    turtle.fd(95)
    turtle.seth(-12)
    turtle.circle(450,40)
    turtle.seth(110)
    turtle.fd(70)
    turtle.seth(213)
    turtle.circle(-345,64)
    turtle.pu()
    turtle.end_fill() 


def body():
    
    #配置画笔属性
    turtle.fillcolor("black") 
    turtle.color("black") 
    turtle.speed(1)
    turtle.colormode(255)

    #绘制母企鹅的身体
    turtle.pu()
    turtle.goto(-489,82)
    turtle.seth(-115)
    turtle.pd()
    turtle.begin_fill() 
    turtle.fd(175)
    turtle.circle(120,40)
    turtle.seth(30)
    turtle.circle(200,40)
    turtle.seth(-90)
    turtle.circle(174,180)
    turtle.seth(-70)
    turtle.circle(200,40)
    turtle.seth(70)
    turtle.circle(120,43)
    turtle.fd(175)
    turtle.seth(213)
    turtle.circle(-345,66)
    turtle.pu()
    turtle.end_fill()


def feet():

    #配置画笔属性
    turtle.fillcolor((250,175,8)) 
    turtle.color((250,175,8)) 
    turtle.speed(1)
    turtle.colormode(255)

    #绘制母企鹅的左脚
    turtle.pu()
    turtle.goto(-300,-228)
    turtle.seth(180)
    turtle.pd()
    turtle.begin_fill() 
    turtle.fd(200)
    turtle.circle(-10,120)
    turtle.circle(-120,40)
    turtle.pu()
    turtle.end_fill()

    #绘制母企鹅的右脚
    turtle.pu()
    turtle.goto(-300,-228)
    turtle.seth(0)
    turtle.pd()
    turtle.begin_fill() 
    turtle.fd(200)
    turtle.circle(10,120)
    turtle.circle(120,50)
    turtle.pu()
    turtle.end_fill()


def belly():

    #配置画笔属性
    turtle.fillcolor("white") 
    turtle.color("white") 
    turtle.speed(1)
    turtle.colormode(255)

    #绘制母企鹅的白色肚皮
    turtle.pu()
    turtle.goto(-305,28)
    turtle.seth(180)
    turtle.pd()
    turtle.begin_fill() 

    #画椭圆
    a=4.5
    for i in range(120):
        if 0<=i<30 or 60<=i<90:
            a=a+0.1
            turtle.lt(3) 
            turtle.fd(a) 
        else:
            a=a-0.1
            turtle.lt(3)
            turtle.fd(a)
    turtle.pu()
    turtle.end_fill()
    turtle.pu()
    turtle.end_fill()    

turtle.Turtle().screen.delay(0)

head();
bowknot();
lefteye();
righteye();
mouth();
feet();
body();
belly();
scarf();
turtle.hideturtle()
turtle.mainloop()

# %%
import turtle as tt
from random import randint
tt.TurtleScreen._RUNNING = True
tt.speed(0)  # 绘图速度为最快
tt.bgcolor("black")  # 背景色为黑色
tt.setpos(-25, 25)  # 改变初始位置，这可以让图案居中
tt.colormode(255)  # 颜色模式为真彩色
cnt = 0
while cnt < 1000:
    r = randint(0, 255)
    g = randint(0, 255)
    b = randint(0, 255)
    tt.pencolor(r, g, b)  # 画笔颜色每次随机
    tt.forward(5 + cnt)
    tt.right(91)
    cnt += 1
tt.done()

# %%
import turtle as tt
tt.TurtleScreen._RUNNING = True  # 启动绘图，在IDE中运行加这句可避免报错
cnt = 0
while cnt < 100:
    tt.forward(200)
    tt.right(101)
    cnt += 1
tt.done()  # 结束绘图，这将不会关闭

# %% [markdown]
# # Files are buffered and seekable.

# %% [markdown]
# The prior paragraph’s notes about closing files are important, because closing both
# frees up operating system resources and flushes output buffers. By default, output
# files are always buffered, which means that text you write may not be transferred
# from memory to disk immediately—closing a file, or running its flush method,
# forces the buffered data to disk. You can avoid buffering with extra open arguments,
# but it may impede performance. Python files are also random-access on a byte offset
# basis—their seek method allows your scripts to jump around to read and write at
# specific locations.

# %% [markdown]
# # Files in Action

# %%
myfile = open('myfile.txt','w') # Open for text output: create/empty

# %%
myfile.write('hello text file\n')
# Out:
# 16

# %%
myfile.write('goodbye text file\n')
# Out:
# 18

# %%
myfile.close() # Flush output buffers to disk

# %%
myfile = open('myfile.txt') # Open for text input: 'r' is default
print(myfile.readline()) # Read the lines back
print(myfile.readline()) # 
print(myfile.readline())
# Out:
# hello text file
#
# goodbye text file

# %%
open('myfile.txt').read()
# Out:
# 'hello text file\ngoodbye text file\n'

# %%
open('alice.txt','r',encoding='UTF-8').read()
# Out:
# '开会了，谁理你\n如果是我自己的，我就使劲打\n是你踢吗\n真打重了他会哭\n下不了手\n他又有点可爱\n他太爱拖拉了，好烦\n喊我侄子回来做作业\n不要有太多人际交往，家庭为重\n不是说过了\n所以不联系啊\n我现在就是讲一件事的心情啊，没什么不开心的\n？？？\n所以就不继续啦\n还不会顶嘴，发脾气\n所以如果你想要未来的妻子也只照顾你的话，保姆就可以啦\n他的未来生活规划里只是把我当做照顾他的角色，对我家人态度不好等，所以分了\n不想说\n我脾气很差\n就见一次面而已，我的脾性你都不清楚\n我没问为什么\n你很喜欢我？\n很想问你个事\n风格突变啊\n突然这么抒情\n净净：还没过关呢\n净净：你啥梦\n有个大侄子就够啦\n还没过关呢\n看来跟我说话拉低你能力啊\n非要比喻牛的话\n又让你大开眼界了\n是因为什么结束呢\n你有过几次恋爱\n你不想说分手原因就算了\n没联系了吧\n那就好\n空气\n细胳膊细腿\n哪敢打你\n哼，跟你说不到一块去\n不然家庭地位不高\n感觉这样也不太好\n我不会攒钱啊\n我也没钱攒\n那怎么办\n我希望我的生活很简单，工作不要太少，可以忙一点，下班除了回家，或者约朋友出去吃饭逛街\n你对自己以后有什么规划吗\n海南人大部分人思想很保守，好多人年轻人都没出过岛\n我也给不了什么好的建议啊\n可能我接触的行业跟你专业差太多\n海南的经济贸易港重心还没确定下来么\n海南不适合你\n你现在就是要在深圳工作，是吗\n我对游泳也不感兴趣'

# %%
open('alice1.txt','r',encoding='UTF-8').read()
# Out:
# '开会了，谁理你\n不开玩笑了，我要做事情了\n不然四肢后天不健全呀\n感觉要一个扮红脸，一个扮白脸的\n完了，如果我也打的话，那孩子在家里岂不是混不下去了\n如果是我自己的，我就使劲打\n开玩笑式地踢嘛，让她知道好歹\n要知道，打是爱\n是你踢吗\n照踢不误\n我姐姐的女儿不可爱么？\n真打重了他会哭\n下不了手\n他又有点可爱\n或者像我姐一样，一脚给他踢飞了\n像打我一样，揍他\n他太爱拖拉了，好烦\n你现在越来越有母亲范儿了\n想起来小时候，经常被我妈妈喊回家吃饭了\n喊我侄子回来做作业\n你现在在做什么？\n说起来，人这一生基本上就是为了一个家而已，无论是工作，学习，还是别的\n红尘碌碌，感觉一个家才能给人安全感\n不要有太多人际交往，家庭为重\n或者有没有一个大的方向？\n简单在哪？\n不是说过了\n你对未来有没有规划没有？\n所以不联系啊\n看得开就行\n但是也辜负你的青春啊\n我现在就是讲一件事的心情啊，没什么不开心的\n人生已经如此艰难，把过去的不快乐事情全忘了吧\n？？？\n这些事情你不要再去想了\n嗯嗯，早分开好一点\n所以就不继续啦\n从对你家人态度来看\n他显然不是真正爱你\n还不会顶嘴，发脾气\n精辟\n哈哈\n所以如果你想要未来的妻子也只照顾你的话，保姆就可以啦\n看起来他是建国前时代的人啊\n他的未来生活规划里只是把我当做照顾他的角色，对我家人态度不好等，所以分了\n如果你不想讲的话，可以不讲\n好\n你谈过几次呀？\n不想说\n我感觉到的，好像比你预期的还多\n我脾气很差\n你知道吗，我很相信我自己的直觉的，不论是在学习中，还是生活中\n就见一次面而已，我的脾性你都不清楚\n帮你节省一下问题嘛\n我没问为什么\n你真要我说为什么，我也不知道\n其实说起来，是一种很抽象的感觉，感觉对了\n你很喜欢我？\n你说\n很想问你个事\n自然流露\n我之前是什么风格？\n风格突变啊\n突然这么抒情\n他帮不了\n这事情跟大侄子没啥关系\n我：需要你，时不时指引我去追梦\n净净：还没过关呢\n我：在城市里面，面朝大海，春暖花开\n净净：你啥梦\n有个大侄子就够啦\n哦哦， 我理解错了\n所以需要你，时不时跟我指引一下怎么做\n还没过关呢\n没事儿，活在当下，当然可以在追梦的同时，享受一下生活\n不知道为啥，IQ这几天下降的厉害\n看来跟我说话
# ...

# %%
print(open('alice1.txt','r',encoding='UTF-8').read())
# Out:
# 开会了，谁理你
# 不开玩笑了，我要做事情了
# 不然四肢后天不健全呀
# 感觉要一个扮红脸，一个扮白脸的
# 完了，如果我也打的话，那孩子在家里岂不是混不下去了
# 如果是我自己的，我就使劲打
# 开玩笑式地踢嘛，让她知道好歹
# 要知道，打是爱
# 是你踢吗
# 照踢不误
# 我姐姐的女儿不可爱么？
# 真打重了他会哭
# 下不了手
# 他又有点可爱
# 或者像我姐一样，一脚给他踢飞了
# 像打我一样，揍他
# 他太爱拖拉了，好烦
# 你现在越来越有母亲范儿了
# 想起来小时候，经常被我妈妈喊回家吃饭了
# 喊我侄子回来做作业
# 你现在在做什么？
# 说起来，人这一生基本上就是为了一个家而已，无论是工作，学习，还是别的
# 红尘碌碌，感觉一个家才能给人安全感
# 不要有太多人际交往，家庭为重
# 或者有没有一个大的方向？
# 简单在哪？
# 不是说过了
# 你对未来有没有规划没有？
# 所以不联系啊
# 看得开就行
# 但是也辜负你的青春啊
# 我现在就是讲一件事的心情啊，没什么不开心的
# 人生已经如此艰难，把过去的不快乐事情全忘了吧
# ？？？
# 这些事情你不要再去想了
# 嗯嗯，早分开好一点
# 所以就不继续啦
# 从对你家人态度来看
# 他显然不是真正爱你
# 还不会顶嘴，发脾气
# 精辟
# 哈哈
# 所以如果你想要未来的妻子也只照顾你的话，保姆就可以啦
# 看起来他是建国前时代的人啊
# 他的未来生活规划里只是把我当做照顾他的角色，对我家人态度不好等，所以分了
# 如果你不想讲的话，可以不讲
# 好
# 你谈过几次呀？
# 不想说
# 我感觉到的，好像比你预期的还多
# 我脾气很差
# 你知道吗，我很相信我自己的直觉的，不论是在学习中，还是生活中
# 就见一次面而已，我的脾性你都不清楚
# 帮你节省一下问题嘛
# 我没问为什么
# 你真要我说为什么，我也不知道
# 其实说起来，是一种很抽象的感觉，感觉对了
# 你很喜欢我？
# 你说
# 很想问你个事
# 自然流露
# 我之前是什么风格？
# 风格突变啊
# 突然这么抒情
# 他帮不了
# 这事情跟大侄子没啥关系
# 我：需要你，时不时指引我去追梦
# 净净：还没过关呢
# 我：在城市里面，面朝大海，春暖花开
# 净净：你啥梦
# 有个大侄子就够啦
# 哦哦， 我理解错了
# ...

# %%
for line in open('1.txt'):
    print(line,end='')
# Out:
# Using Files
# Once you make a file object with open, you can call its methods to read from or write
# to the associated external file. In all cases, file text takes the form of strings in Python
# programs; reading a file returns its text in strings, and text is passed to the write methods
# as strings. Reading and writing methods come in multiple flavors; Table 9-2 lists the
# most common. Here are a few fundamental usage notes:
# File iterators are best for reading lines
# Though the reading and writing methods in the table are common, keep in mind
# that probably the best way to read lines from a text file today is to not read the file
# at all鈥攁s we鈥檒l see in Chapter 14, files also have an iterator that automatically reads
# one line at a time in a for loop, list comprehension, or other iteration context.
# Content is strings, not objects
# Notice in Table 9-2 that data read from a file always comes back to your script as
# ...
